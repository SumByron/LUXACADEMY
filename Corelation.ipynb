# %% [markdown]
# ## CORELATION

# %%
import pandas as pd
import numpy as np
import datetime as date

# %%
from datetime import date
cd = date.today()

print (cd)
# Out:
# 2025-02-13

# %%
x = (2,3,4)
y = (5,6,7)

# %%
import numpy as np
x = np.array([2,3,4])
y = np.array([5,6,7])

#Calculating the corelation matrix
corelation_matrix = np.corrcoef(x,y)

print(corelation_matrix)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
import pandas as pd

try:
    df=pd.read_csv("train_data_cross-sell.csv",encoding="latin1")

except Exception as e:
        print(f"Error reading file:{e}")
df.head()
# Out:
#          ÿid  Gender       Customer_Date_of_Birth  Driving_License  \
# 0  549771831    Male        Monday, March 7, 1977                1
# 1  373583351    Male    Sunday, December 29, 2002                1
# 2  933163655  Female     Tuesday, August 23, 1994                1
# 3  698942186  Female  Thursday, November 18, 1999                1
# 4  515109822    Male  Thursday, February 22, 2001                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium      Agent_name  \
# 0                         2020            Yes           38294   Jomo Kenyatta
# 1                         2020             No           28619  Obiero Ochieng
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Seting up the matplotlib figure
plt.figure(figsize=(10, 8))

# Drawing the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, cmap="Greys", annot=True, fmt=".2f", linewidths=.5)

# Add title
plt.title('Correlation Matrix')

# Show plot
plt.show()

# %%
from datetime import datetime
current_year = datetime.now ().year
current_year
# Out:
# 2025

# %%
current_year = datetime.now().year
df['Age'] = current_year - df['Customer_Date_of_Birth'].dt.year

# %%
df.head()
# Out:
#    Gender Customer_Date_of_Birth  Driving_License  Previously_Insured  \
# 0       1             1977-03-07                1                   0
# 1       1             2002-12-29                1                   1
# 2       0             1994-08-23                1                   1
# 3       0             1999-11-18                1                   0
# 4       1             2001-02-22                1                   0
#
#    Vehicle_Year_of_Manufacture  Vehicle_Damage  Annual_Premium  \
# 0                         2020               1           38294
# 1                         2020               0           28619
# 2                         2011               0           27496
# 3                         2020               1            2630
# 4                         2015               1           23367
#
#         Life_policy_start_date  Response  Age
# 0  Thursday, December 21, 2023         1   48
# 1     Wednesday, June 28, 2023         0   23
# ...

# %%
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])  # Male = 1, Female = 0
df['Vehicle_Damage'] = le.fit_transform(df['Vehicle_Damage'])  # Yes = 1, No = 0
df.head()
# Out:
#    Gender Customer_Date_of_Birth  Driving_License  Previously_Insured  \
# 0       1             1977-03-07                1                   0
# 1       1             2002-12-29                1                   1
# 2       0             1994-08-23                1                   1
# 3       0             1999-11-18                1                   0
# 4       1             2001-02-22                1                   0
#
#    Vehicle_Year_of_Manufacture  Vehicle_Damage  Annual_Premium  \
# 0                         2020               1           38294
# 1                         2020               0           28619
# 2                         2011               0           27496
# 3                         2020               1            2630
# 4                         2015               1           23367
#
#         Life_policy_start_date  Response  Age
# 0  Thursday, December 21, 2023         1   48
# 1     Wednesday, June 28, 2023         0   23
# ...

# %%
#  Drop the specified columns
df.drop(columns=['ÿid', 'Agent_name', 'Customer_Residence_Sub_County', 'Life_policy_start_date'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 2
#       1 #  Drop the specified columns
# ----> 2 df.drop(columns=['ÿid', 'Agent_name', 'Customer_Residence_Sub_County', 'Life_policy_start_date'], inplace=True)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
# ...

# %%
df.head()
# Out:
#    Gender Customer_Date_of_Birth  Driving_License  Previously_Insured  \
# 0       1             1977-03-07                1                   0
# 1       1             2002-12-29                1                   1
# 2       0             1994-08-23                1                   1
# 3       0             1999-11-18                1                   0
# 4       1             2001-02-22                1                   0
#
#    Vehicle_Year_of_Manufacture  Vehicle_Damage  Annual_Premium  \
# 0                         2020               1           38294
# 1                         2020               0           28619
# 2                         2011               0           27496
# 3                         2020               1            2630
# 4                         2015               1           23367
#
#         Life_policy_start_date  Response  Age
# 0  Thursday, December 21, 2023         1   48
# 1     Wednesday, June 28, 2023         0   23
# ...

# %%
df.drop(columns = ['Life_policy_start_date', 'Customer_Date_of_Birth'])
# Out:
#         Gender  Driving_License  Previously_Insured  \
# 0            1                1                   0
# 1            1                1                   1
# 2            0                1                   1
# 3            0                1                   0
# 4            1                1                   0
# ...        ...              ...                 ...
# 324461       1                1                   0
# 324462       1                1                   1
# 324463       1                1                   1
# 324464       1                1                   1
# 324465       0                1                   0
#
#         Vehicle_Year_of_Manufacture  Vehicle_Damage  Annual_Premium  Response  \
# 0                              2020               1           38294         1
# 1                              2020               0           28619         0
# 2                              2011               0           27496         0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Compute the correlation matrix
correlation_matrix = df.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix of Independent Variables")
plt.show()



# NB this one has not  droped the response  column which is our dependent variable
