# %% [markdown]
# ## DATA VISUALIZATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
try:
    df=pd.read_csv("train_data_cross-sell.csv",encoding="latin1")
    df.rename(columns={"ÿid":"ID"},inplace=True)
except Exception as e:
        print(f"Error reading file:{e}")
df.head()
# Out:
#           ID  Gender       Customer_Date_of_Birth  Driving_License  \
# 0  549771831    Male        Monday, March 7, 1977                1
# 1  373583351    Male    Sunday, December 29, 2002                1
# 2  933163655  Female     Tuesday, August 23, 1994                1
# 3  698942186  Female  Thursday, November 18, 1999                1
# 4  515109822    Male  Thursday, February 22, 2001                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium      Agent_name  \
# 0                         2020            Yes           38294   Jomo Kenyatta
# 1                         2020             No           28619  Obiero Ochieng
# ...

# %%
top_ten_agents = df.groupby = df.groupby('Agent_name')['Annual_Premium'].sum().reset_index()

# %%
top_ten_agents = top_ten_agents.sort_values(by='Annual_Premium',ascending=False)

# %%
top_ten_agents = top_ten_agents.head(10)
top_ten_agents
# Out:
#           Agent_name  Annual_Premium
# 124   Obiero Ochieng      3540111121
# 22     Jomo Kenyatta      2284661069
# 105  Njoroge Karanja      1997845221
# 18    Gitonga Mwangi       475238042
# 41     Kimani Mwenda       312278181
# 6        Chege Nyaga       144430207
# 130   Onyango Mariga       103846148
# 38      Kibet Makori        97722877
# 115      Nyaga Kibet        79467053
# 27   Karanja Wanjala        60298000

# %%
plt.figure(figsize = (8,5))
plt.barh(top_ten_agents['Agent_name'],top_ten_agents['Annual_Premium'],color = 'red')
plt.xlabel('Annual_Premium')
plt.ylabel('Agent_Name')
# Out:
# Text(0, 0.5, 'Agent_Name')

# %%
for index,value in enumerate['Annual_Premium']:
    plt.text(value + 200, index, str(value), fontsize=10, va='center')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 for index,value in enumerate['Annual_Premium']:
#       2     plt.text(value + 200, index, str(value), fontsize=10, va='center')
#       4 plt.tight_layout()
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
#Converting the DOB into a recognizable date and calculating age/craeting the Age column
df["Customer_Date_of_Birth"] = pd.to_datetime(df["Customer_Date_of_Birth"])
current_year = datetime.now().year
df["Age"] = current_year - df["Customer_Date_of_Birth"].dt.year

# %%
# Create Box Plot
plt.figure(figsize=(8,6))  
plt.boxplot(df['Age'], vert=False, patch_artist=True, boxprops=dict(facecolor="grey"))

# Titles and Labels
plt.title("Box Plot of Policy Holder Ages", fontsize=16)
plt.xlabel("Age", fontsize=12)

# Show the plot
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %%
# Create Box Plot using the sns in place for plt and changing color to orange and the vert = true from false

plt.figure(figsize=(8,6))  
sns.boxplot(df['Age'], vert=True, patch_artist=True, boxprops=dict(facecolor="orange"))

# Titles and Labels
plt.title("Box Plot of Policy Holder Ages", fontsize=14)
plt.xlabel("Age", fontsize=12)

# Show the plot
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %%
#Using seaborn to generate a box plot
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# Convert 'Customer_Date_of_Birth' to datetime
df['Customer_Date_of_Birth'] = pd.to_datetime(df['Customer_Date_of_Birth'])

# Calculate Age
current_year = datetime.now().year
df['Age'] = current_year - df['Customer_Date_of_Birth'].dt.year

# Create Box Plot using Seaborn
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Age'], color='lightcoral')

# Titles and Labels
plt.title("Box Plot of Policy Holder Ages", fontsize=16)
plt.xlabel("Age", fontsize=12)

# Show the plot
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
import pandas as pd

try:
    df=pd.read_csv("train_data_cross-sell.csv",encoding="latin1")

except Exception as e:
        print(f"Error reading file:{e}")
df.head()
# Out:
#          ÿid  Gender       Customer_Date_of_Birth  Driving_License  \
# 0  549771831    Male        Monday, March 7, 1977                1
# 1  373583351    Male    Sunday, December 29, 2002                1
# 2  933163655  Female     Tuesday, August 23, 1994                1
# 3  698942186  Female  Thursday, November 18, 1999                1
# 4  515109822    Male  Thursday, February 22, 2001                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium      Agent_name  \
# 0                         2020            Yes           38294   Jomo Kenyatta
# 1                         2020             No           28619  Obiero Ochieng
# ...

# %%
df.head()
# Out:
#          ÿid  Gender       Customer_Date_of_Birth  Driving_License  \
# 0  549771831    Male        Monday, March 7, 1977                1
# 1  373583351    Male    Sunday, December 29, 2002                1
# 2  933163655  Female     Tuesday, August 23, 1994                1
# 3  698942186  Female  Thursday, November 18, 1999                1
# 4  515109822    Male  Thursday, February 22, 2001                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium      Agent_name  \
# 0                         2020            Yes           38294   Jomo Kenyatta
# 1                         2020             No           28619  Obiero Ochieng
# ...

# %%
df = df.drop(columns = ['Customer_Residence_Sub_County','ÿid','Agent_name'] ) 
df.head()
# Out:
#    Gender       Customer_Date_of_Birth  Driving_License  Previously_Insured  \
# 0    Male        Monday, March 7, 1977                1                   0
# 1    Male    Sunday, December 29, 2002                1                   1
# 2  Female     Tuesday, August 23, 1994                1                   1
# 3  Female  Thursday, November 18, 1999                1                   0
# 4    Male  Thursday, February 22, 2001                1                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium  \
# 0                         2020            Yes           38294
# 1                         2020             No           28619
# 2                         2011             No           27496
# 3                         2020            Yes            2630
# 4                         2015            Yes           23367
#
#         Life_policy_start_date  Response
# 0  Thursday, December 21, 2023         1
# 1     Wednesday, June 28, 2023         0
# ...

# %%
df.head()
# Out:
#    Gender       Customer_Date_of_Birth  Driving_License  Previously_Insured  \
# 0    Male        Monday, March 7, 1977                1                   0
# 1    Male    Sunday, December 29, 2002                1                   1
# 2  Female     Tuesday, August 23, 1994                1                   1
# 3  Female  Thursday, November 18, 1999                1                   0
# 4    Male  Thursday, February 22, 2001                1                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium  \
# 0                         2020            Yes           38294
# 1                         2020             No           28619
# 2                         2011             No           27496
# 3                         2020            Yes            2630
# 4                         2015            Yes           23367
#
#         Life_policy_start_date  Response
# 0  Thursday, December 21, 2023         1
# 1     Wednesday, June 28, 2023         0
# ...

# %%
from datetime import date
cd = date.today().year

df["Customer_Date_of_Birth"] = pd.to_datetime(df["Customer_Date_of_Birth"])
df["Age"] = cd - df["Customer_Date_of_Birth"].dt.year

# %%
df["Customer_Date_of_Birth"] = pd.to_datetime(df["Customer_Date_of_Birth"])

# %%
cd = datetime.now().year

# %%
df["Age"] = cd - df["Customer_Date_of_Birth"].dt.year

df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 df["Age"] = cd - df["Customer_Date_of_Birth"].dt.year
#       3 df.head()
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df["Life_policy_start_date"] = pd.to_datetime(df["Life_policy_start_date"])

# %%
df["Tenure"] = cd - df["Life_policy_start_date"].dt.year

# %%
df = df.drop(columns = ['Life_policy_start_date'])

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder

unique_counts - df.nunique()

columns_to_encode = unique_counts[unique_counts <= 2].index.tolist()


le = LabelEncoder()
for col in columns_to_encode:
    df[col] - le.fit_transform(df[col])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming you have data in a CSV file named 'data.csv'
import pandas as pd


unique_counts = df.nunique()
columns_to_encode = unique_counts[unique_counts <= 2].index.tolist()
le = LabelEncoder()

for col in columns_to_encode:
    df[col] = le.fit_transform(df[col])

df.head()
# Out:
#    Gender       Customer_Date_of_Birth  Driving_License  Previously_Insured  \
# 0       1        Monday, March 7, 1977                1                   0
# 1       1    Sunday, December 29, 2002                1                   1
# 2       0     Tuesday, August 23, 1994                1                   1
# 3       0  Thursday, November 18, 1999                1                   0
# 4       1  Thursday, February 22, 2001                1                   0
#
#    Vehicle_Year_of_Manufacture  Vehicle_Damage  Annual_Premium  Response  \
# 0                         2020               1           38294         1
# 1                         2020               0           28619         0
# 2                         2011               0           27496         0
# 3                         2020               1            2630         0
# 4                         2015               1           23367         0
#
#    Tenure
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
Genders = df ['Gender'].value_counts()

plt.figure(figsize=(10,6))
plt.pie(gender)

# %%
df = df.drop(columns = ['Tenure','Customer_Date_of_Birth'] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 df = df.drop(columns = ['Tenure','Customer_Date_of_Birth'] )
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df.head()
# Out:
#    Gender  Driving_License  Previously_Insured  Vehicle_Year_of_Manufacture  \
# 0       1                1                   0                         2020
# 1       1                1                   1                         2020
# 2       0                1                   1                         2011
# 3       0                1                   0                         2020
# 4       1                1                   0                         2015
#
#    Vehicle_Damage  Annual_Premium  Response
# 0               1           38294         1
# 1               0           28619         0
# 2               0           27496         0
# 3               1            2630         0
# 4               1           23367         0

# %%
y =df[response]
x = df drop (y)
# Out:
#   Cell In[199], line 2
#     x = df drop (y)
#            ^
# SyntaxError: invalid syntax

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Calculate the correlation matrix
corr_matrix = df.corr()

# Print the correlation matrix (optional)
print(corr_matrix)

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Generate a heatmap with the correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Add title and labels
plt.title('Correlation Heatmap')
plt.xlabel('Variables')
plt.ylabel('Variables')

# Show the plot
plt.show()
# Out:
#                                Gender  Driving_License  Previously_Insured  \
# Gender                       1.000000        -0.017559           -0.080665
# Driving_License             -0.017559         1.000000            0.014507
# Previously_Insured          -0.080665         0.014507            1.000000
# Vehicle_Year_of_Manufacture  0.002036         0.000916            0.002715
# Vehicle_Damage               0.090602        -0.016720           -0.824459
# Annual_Premium               0.003636        -0.012270            0.004200
# Response                     0.051280         0.009762           -0.341402
#
#                              Vehicle_Year_of_Manufacture  Vehicle_Damage  \
# Gender                                          0.002036        0.090602
# Driving_License                                 0.000916       -0.016720
# Previously_Insured                              0.002715       -0.824459
# Vehicle_Year_of_Manufacture                     1.000000       -0.000956
# ...
